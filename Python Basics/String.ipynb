# %% [markdown]
# # Strings (' ', " ", str() )
#
# * Sequence of Characters
# * Immutable, ordered sequence of characters (e.g., letters, numbers, spaces, and symbols)
#
# Lists vs Stings
# * lists and strings both support indexing, slicing, and membership operators
# * both strings and lists are ordered (indexing works well for them)
# * differences - lists can be modified but strings cant, i.e., lists is mutable data type and strings is a immutable data type

# %% [markdown]
# * How to create a string
# * Escape Sequences
# * Playing with strings
# * Concatenate Strings
# * Replicate Strings
# * stings and sequences
#     * Indexing
#     * Negative Indexing
#     * Slicing
#     * Stride
#     * How long is the string
#     * Loops in strings
#     * string are immutable and we can't modify them
# * String operations
# * String Methods - help(str), help(str.upper) to see list of more methods
#     * len() - is a function not method
#     * upper()
#     * lower()
#     * swapcase() - swaps the case string.swapcase()
#     * title() - method returns a copy of the string
#     * index()
#     * startswith() # help(str.startswith)
#     * endswith()
#     * split() -Return a list of the words in the string, using sep as the delimiter string.
#     * join()
#     * count()
#     * find() - Return the lowest index in String where substring sub is found
#     * rfind()
#     * strip() -Return a copy of the string with leading and trailing whitespace remove. # strip(' .,') removes whitespace, , and .
#     * replace()
#     * str.rjust # help(str.rjust) - Return a right-justified string of length width.- one eg. in dictionariesInPython notebook
#     * isnumeric() # eg in FunctionsInPython
#     * isdigit() # eg in FunctionsInPython
#     * casefold() - case sensative -Return a version of the string suitable for caseless comparisons. (FunctionsInPython and one e.g. below)
# * Concatenate Strings with  + operator
#     * str() # Type casting -to convert other data types, e.g., int to string
#     * str.format()
#         * decimal places
#         * comma seperation
#         * format() arguments by index - starting from 0
#         * more on str.format() -https://pyformat.info, https://docs.python.org/3/library/string.html#formatstrings
#     * capitalize() - Make the first character have uppercase and rest lower
#     * center - return a centered string of length width. padding is done using arguments
#     * encode - Encoding the string using the codec registered for encoding
#     * isalnum() - Returns True if the string is a alpha-numeric string, False otherwise
#     * isalpha() - Return True if the string is an alphabetic string, False otherwise.
#     * isdecimal() - Return True if the string is a decimal string, False otherwise.
#     * isdigit() - Return True if the string is a digit string, False otherwise.
#     * isidentifier() -Return True if the string is a valid Python identifier, False otherwise.
#     * islower() -Return True if the string is a lowercase string, False otherwise.
#     * isnumeric() -Return True if the string is a numeric string, False otherwise.
#     * isprintable() - Return True if the string is printable, False otherwise.
#     * isspace() - Return True if the string is a whitespace string, False otherwise.
#     * istitle() - Return True if the string is a title-cased string, False otherwise.
#     * isupper() - Return True if the string is an uppercase string, False otherwise.
#     * join() - Concatenate any number of strings.
#     * ljust() -Return a left-justified string of length width.

# %%
# Strings in Python are shown as the variable type str.
# Strings in Python can be defined using either single 'hello' or double quotations "hello".

x = "Pluto is a planet"
y = 'Pluto is a planet'
x==y #True 

# A string can be a combination of spaces and digits
'1 2 3 4 5 6 '

# A string can also be a combination of special characters 
'@#2_#]&*^%$'
# Out:
# True

# %%
type('7.1') #str
# Out:
# str

# %%
# string is immutable -This means to change this string, you will need to create a completely new string.
greeting = "Hellow there" # "Hellow there"  is a immutable object 
greeting[5] #'w'
greeting[5] = 'W'#TypeError: 'str' object does not support item assignment

# OBS immutable obejct "Hellow there" and variable that holds immutable obejct can change as the value of that 
#   immutable object is saved in memory (the variable can change but not immutable obejct)

name = 'Jim'
student = name
name = 'Tim'

# We can print our string using the print statement
print(name) # Tim
print(student) #Jim
# Out:
# Tim
# Jim

# %%
# Similarly, it's easy to create a string that contains double-quotes if you wrap it in single quotes:

print("Pluto's a planet!") # String containing ' (single quote) #Pluto's a planet!
print('My dog is named "Pluto"') # String containing " (double quotes) #My dog is named "Pluto"

# If we try to put a single quote character inside a single-quoted string, Python gets confused:
# We can fix this by "escaping" the single quote with a backslash.
print('Pluto\'s a planet!') # Pluto's a planet
# Out:
# Pluto's a planet!
# My dog is named "Pluto"
# Pluto's a planet!
# hello
# world

# %% [markdown]
# ## Escape Sequences

# %% [markdown]
# Back slashes represent the beginning of escape sequences. Escape sequences represent strings that may be difficult to input. For example, back slash "n" represents a new line. The output is given by a new line after the back slash "n" is encountered:

# %%
print("hello\nworld") # \n new line sequence

# %% [markdown]
# Similarly, back slash "t" represents a tab:

# %%
print(" Michael Jackson \t is the best" )
# Out:
#  Michael Jackson 	 is the best

# %% [markdown]
# If you want to place a back slash in your string, use a double back slash:

# %%
# Include back slash in string

print(" Michael Jackson \\ is the best" )
print("\\\\") #\\
# Out:
#  Michael Jackson \ is the best

# %% [markdown]
# We can also place an "r" before the string to display the backslash:

# %%
# r will tell python that string will be display as raw string

print(r" Michael Jackson \ is the best" ) # Michael Jackson \ is the best
print(r"\ ") #\
# Out:
#  Michael Jackson \ is the best
# \

# %%
# Python's triple quote syntax for strings lets us include newlines literally (i.e. by just hitting 'Enter' on our 
#    keyboard, rather than using the special '\n' sequence). We've already seen this in the docstrings we use to 
#    document our functions, but we can use them anywhere we want to define a string.

triplequoted_hello = """hello
world"""
print(triplequoted_hello)
# Out:
# hello
# world

# %%
# The print() function automatically adds a newline character unless we specify a value for the keyword argument end 
#   other than the default value of '\n':

print("hello")
print("world")
print("hello", end='')
print("pluto", end='') #hellopluto
# Out:
# hello
# world
# hellopluto

# %% [markdown]
# The table below summarizes some important uses of the backslash character
#
# ![Screenshot%202021-08-16%20at%2019.43.11.jpg](attachment:Screenshot%202021-08-16%20at%2019.43.11.jpg)

# %% [markdown]
# ## Concatenate Strings

# %% [markdown]
# We can concatenate or combine strings by using the addition symbols, and the result is a new string that is a combination of both:

# %%
# There are a number of other operations you can use with strings as well. 

# Combine Strings / Concatenate Strings 
first_word = 'Hello'
second_word = 'There'
print(first_word + second_word) #HelloThere

# Ex 
# Checking your variable types is really important to assure that you are retrieving the results you want when 
#   programming.
print("0" + "5") #'05'
print("0" + 5) #Error 
print(0 + "5") #Error 

str(1)+str(1) #'11'

# To add a space in between 
print(first_word + ' ' + second_word) #Hello There

# %% [markdown]
# ## Replicate Strings

# %% [markdown]
# To replicate values of a string we simply multiply the string by the number of times we would like to replicate it. In this case, the number is 5. The result is a new string, and this new string consists of 5 copies of the original string:

# %%
# Repeat Strings 
print(first_word * 5) #HelloHelloHelloHelloHello

# %% [markdown]
# ## Strings and sequences
#
# Strings can be thought of as sequences of characters. Almost everything we've seen that we can do to a list, we can also do to a string.
#
# But a major way in which they differ from lists is that they are immutable. We can't modify them.

# %% [markdown]
# ## Indexing

# %% [markdown]
# It is helpful to think of a string as an ordered sequence. Each element in the sequence can be accessed using an index represented by the array of numbers:

# %% [markdown]
# ![Screenshot%202021-12-05%20at%2011.03.39.jpg](attachment:Screenshot%202021-12-05%20at%2011.03.39.jpg)

# %%
# The first element can be accessed as follows

#   P  l u  t  o
#  0  1  2  3  4
# -5 -4 -3 -2 -1

planet = 'Pluto'
planet[0] # 'P'

# %% [markdown]
# ## Negative Indexing

# %% [markdown]
# Negative index can help us to count the element from the end of the string.

# %% [markdown]
# ![Screenshot%202021-12-05%20at%2011.08.28.jpg](attachment:Screenshot%202021-12-05%20at%2011.08.28.jpg)

# %%
#The last element is given by the index -1:
pluto[-1] #'n' 

#The first element can be obtained by index -5
pluto[-5] #'P'

# %% [markdown]
# ##  Slicing

# %% [markdown]
# We can obtain multiple characters from a string using slicing, we can obtain the 0 to 4th and 8th to the 12th element

# %% [markdown]
# ![Screenshot%202021-12-05%20at%2011.27.30.jpg](attachment:Screenshot%202021-12-05%20at%2011.27.30.jpg)

# %%
name = "Michael Jackson"

# Take the slice on variable name with only index 0 to index 3
name[0:4] #'Mich'

# Take the slice on variable name with only index 8 to index 11
name[8:12] #'Jack'
# Out:
# 'Jack'

# %% [markdown]
# ## Stride

# %% [markdown]
# We can also input a stride value as follows, with the '2' indicating that we are selecting every second variable:

# %% [markdown]
# ![Screenshot%202021-12-05%20at%2011.31.55.jpg](attachment:Screenshot%202021-12-05%20at%2011.31.55.jpg)

# %%
# Get every second element. The elments on index 1, 3, 5 ...

name[::2] #'McalJcsn'

# Use a stride value of 2 to print out every second character of the string e:
e = 'clocrkr1e1c1t'
e[::2] #'correct'
# Out:
# 'McalJcsn'

# %% [markdown]
# We can also incorporate slicing with the stride. In this case, we select the first five elements and then use the stride:

# %%
# Get every second element in the range from index 0 to index 4

name[0:5:2] #'Mca'
# Out:
# 'Mca'

# %%
# Loops in strings 
[char+'!' for char in planet] # ['P!', 'l!', 'u!', 't!', 'o!']
# Out:
# ['P!', 'l!', 'u!', 't!', 'o!']

# %%
# We cant modify strings, i.e., they are immutable 
planet[0]='B'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-446547ac6f60> in <module>
#       1 # We cant modify strings, i.e., they are immutable
# ----> 2 planet[0]='B'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ## String Operations

# %% [markdown]
# There are many string operation methods in Python that can be used to manipulate the data. We are going to use some basic string operations on the data.

# %% [markdown]
# ## String Methods
#
# Like list, the type str has lots of very useful methods.
#
# Method is a function that "belongs" to an object. object for e.g., being a string
#
# A method in Python behaves similarly to a function. Methods actually are functions that are called using dot notation. For example, lower() is a string method that can be used like this, on a string called "sample string": sample_string.lower().
#
# Methods are specific to the data type for a particular variable.
#
# Each of these methods accepts the string itself as the first argument of the method. However, they also could receive additional arguments, that are passed inside the parentheses.
#
# obs: len() is a function, lower() is method

# %%
# len() is a built-in Python function that returns the length of an object, like a string. 
# The length of a string is the number of characters in the string.

len(planet) # 5

# %%
# Convert all the characters in string to upper case
claim = "Pluto is a planet!"
claim.upper() # 'PLUTO IS A PLANET!'

'hello'.upper() #'HELLO'
# Out:
# 'HELLO'

# %%
# all lower case 
claim.lower() # 'pluto is a planet!'
# Out:
# 'pluto is a planet!'

# %%
# Searching for the first index of a string 
claim.index('e') #15
claim.index('plan') # 11 returns index of first character, i.e., p
# Out:
# 11

# %%
# startswith() - help(str.startswith)

claim.startswith(planet) # True 

# claim = "Pluto is a planet!"
# planet = 'Pluto'
# Out:
# True

# %%
# endswith()

claim.endswith('planet') # False
claim.endswith('planet!') # True
# Out:
# True

# %%
# split() 

# str.split() turns a string into a list of smaller strings, breaking on whitespace by default. This is super 
#   useful for taking you from one big string to a list of words.

words = claim.split() words # ['Pluto', 'is', 'a', 'planet!']

# Eg. count the unique words  
verse = "if you can keep your head when all about you are losing theirs and blaming it on you   if you can trust yourself when all men doubt you     but make allowance for their doubting too   if you can wait and not be tired by waiting      or being lied about  don’t deal in lies   or being hated  don’t give way to hating      and yet don’t look too good  nor talk too wise"

# split verse into list of words
verse_list = verse.split()

# convert list to a data structure that stores unique elements
verse_set = set(verse_list)

# print the number of unique words
num_unique = len(verse_set)
print(num_unique) #51

# %%
# if want to split other than whitespace 
# The split method has two additional arguments (sep and maxsplit). The sep argument stands for "separator". It can be 
#   used to identify how the string should be split up (e.g., whitespace characters like space, tab, return, newline; 
#   specific punctuation (e.g., comma, dashes)). If the sep argument is not provided, the default separator is 
#   whitespace.

# eg of step 
datestr = '1956-01-31'
year, month, day = datestr.split('-')
print(year) # 1956
print(month) # 01


new_str = "The cow jumped over the moon."
new_str.split('.') #['The cow jumped over the moon', '']

# True to its name, the maxsplit argument provides the maximum number of splits. The argument gives maxsplit + 1 number
#   of elements in the new list, with the remaining string being returned as the last element in the list. 

new_str.split(' ', 3) #['The', 'cow', 'jumped', 'over the moon.']

#Using no separators but having a maxsplit argument of 3.
new_str.split(None, 3) #['The', 'cow', 'jumped', 'over the moon.']
# Out:
# 1956
# 01
# ['The', 'cow', 'jumped', 'over the moon.']

# %%
# join()

# str.join() joins  a list of strings up into one long string, using the string  called on as a separator.

'/'.join([month, day, year]) # '01/31/1956'
# Out:
# '01/31/1956'

# %%
# We can put unicode characters right in our string literals :)

' 👏 '.join([word.upper() for word in words])  # print(words) # 'Pluto', 'is', 'a', 'planet!']
# Out:
# 'PLUTO 👏 IS 👏 A 👏 PLANET!'

# %%
print(words)
# Out:
# ['Pluto', 'is', 'a', 'planet!']

# %%
# str.count() - method adds up the number of times a character or sequence of characters appears in a string

s = "That that is is that that is not is not is that it it is"
#s.count("t") #13

s.lower().count("t") # 14
# Out:
# 14

# %%
# str.count() .. continued 

s = "James while John had had had had had had had had had had had a better effect on the teacher"
s.count("had") # 11
# Out:
# 11

# %% [markdown]
# The method find finds a sub-string. The argument is the substring you would like to find, and the output is the first index of the sequence. We can find the sub-string jack or el.

# %% [markdown]
# ![Screenshot%202021-12-05%20at%2012.27.11.jpg](attachment:Screenshot%202021-12-05%20at%2012.27.11.jpg)

# %%
# str.find() - Return the lowest index in Sting where substring sub is found 
# Find the substring in the string. Only the index of the first elment of substring in string will be the output
# str.rfind() - looks for a substring from the end.

name = "Michael Jackson"
name.find('el') #5

# Find the substring in the string.
name.find('Jack') #8
"hello Mike".find("Mike") #6

s = "On the other hand, you have different fingers."
s. find("hand") #13 -The results tell us that “hand” begins at the 13th position in the sequence.

s.find("o") # 7

# But if we want to find the second “o” we need to specify a range.
s.find("o", 8) #20 - This begins searching at the 8th element and finds “o” at 20.

s.find("o", 9, 15) #-1 (not present)

# You can also specificy an end to the range, and, like slicing, we can do so backwards:
s.find("e", 20, -5) #26

s.find("r") #43
s.rfind("r") #43
# Out:
# 43

# %% [markdown]
# If the sub-string is not in the string then the output is a negative one. For example, the string 'Jasdfasdasdf' is not a substring:

# %%
# If cannot find the substring in the string

name.find('Jasdfasdasdf') #-1
# Out:
# -1

# %%
# strip()

string = '  xoxo love xoxo   '

# Leading and trailing whitespaces are removed
print(string.strip())

# All <whitespace>,x,o,e characters in the left
# and right of string are removed
print(string.strip(' xoe'))

# Argument doesn't contain space
# No characters are removed.
print(string.strip('stx'))

string = 'android is awesome'
print(string.strip('an'))
# Out:
# xoxo love xoxo
# lov
#   xoxo love xoxo
# droid is awesome

# %% [markdown]
# The method replace replaces a segment of the string, i.e. a substring with a new string. We input the part of the string we would like to change. The second argument is what we would like to exchange the segment with, and the result is a new string with the segment changed:

# %%
# str.replace()
# # Replace the old substring with the new target substring is the segment has been found in the string

s = "I intend to live forever, or die trying."
s.replace("to", "three") # 'I intend three live forever, or die trying.'


s.replace("fore", "five") # 'I intend to live fivever, or die trying.'

"ABC".replace("AB","ab") #'abC'
# Out:
# 'abC'

# %%
# A researcher has gathered thousands of news articles. But she wants to focus her attention on articles including a 
#    specific word. Complete the function below to help her filter her list of articles.
# Your function should meet the following criteria:
# * Do not include documents where the keyword string shows up only as a part of a larger word. For example, if she 
#    were looking for the keyword “closed”, you would not include the string “enclosed.”
# * She does not want you to distinguish upper case from lower case letters. So the phrase “Closed the case.” would 
#    be included when the keyword is “closed”
# * Do not let periods or commas affect what is matched. “It is closed.” would be included when the keyword is 
#   “closed”. But you can assume there are no other types of punct

def word_search(doc_list, keyword):
    """
    Takes a list of documents (each document is a string) and a keyword. 
    Returns list of the index values into the original list (doc_list) for all documents 
    containing the keyword.

    Example:
    doc_list = ["The Learn Python Challenge Casino.", "They bought a car", "Casinoville"]
    >>> word_search(doc_list, 'casino')
    >>> [0]
    """
    temp=[]
    for x in range(len(doc_list)):
        words=doc_list[x].casefold().split() # ['they', 'bought', 'a', 'car,', 'and', 'a', 'horse']
        # words - takes the first doc string, converts all in small characters and split each word
        # clean - takes each word and remove . and , from that word
        clean = [words[wor].strip(' .,') for wor in range(len(words))] # ['they', 'bought', 'a', 'car', 'and', 'a', 'horse'#]
        if keyword.casefold() in clean:
            temp.append(x)
    return temp

# Test case 1  
#doc_list = ["The Learn Python Challenge Casino.", "They bought a car", "Casinoville"]
#word_search(doc_list, 'casino')

# Test case 2
doc_list=['The Learn Python Challenge Casino', 'They bought a car, and a horse', 'Casinoville?']
word_search(doc_list, 'car')


# casefold() - case sensative -Return a version of the string suitable for caseless comparisons.
# split() - Return a list of the words in the string, using sep as the delimiter string.
# strip() - Return a copy of the string with leading and trailing whitespace remove. # strip(' .,') removes whitespace, , and .

# %%
# Alternative Solution 

def word_search(documents, keyword):
    # list to hold the indices of matching documents
    indices = [] 
    # Iterate through the indices (i) and elements (doc) of documents
    for i, doc in enumerate(documents):
        # Split the string doc into a list of words (according to whitespace)
        tokens = doc.split()
        # Make a transformed list where we 'normalize' each word to facilitate matching.
        # Periods and commas are removed from the end of each word, and it's set to all lowercase.
        normalized = [token.rstrip('.,').lower() for token in tokens]
        # Is there a match? If so, update the list of matching indices.
        if keyword.lower() in normalized:
            indices.append(i)
    return indices

# Test case 1  
#doc_list = ["The Learn Python Challenge Casino.", "They bought a car", "Casinoville"]
#word_search(doc_list, 'casino')

# Test case 2
doc_list=['The Learn Python Challenge Casino', 'They bought a car, and a horse', 'Casinoville?']
word_search(doc_list, 'car')
# Out:
# [1]

# %%
# Now the researcher wants to supply multiple keywords to search for. Complete the function below to help her.
# (You're encouraged to use the word_search function you just wrote when implementing this function. Reusing code 
#    in this way makes your programs more robust and readable - and it saves typing!)
 
def multi_word_search(doc_list, keywords):
    """
    Takes list of documents (each document is a string) and a list of keywords.  
    Returns a dictionary where each key is a keyword, and the value is a list of indices
    (from doc_list) of the documents containing that keyword

    >>> doc_list = ["The Learn Python Challenge Casino.", "They bought a car and a casino", "Casinoville"]
    >>> keywords = ['casino', 'they']
    >>> multi_word_search(doc_list, keywords)
    {'casino': [0, 1], 'they': [1]}
    """
    result={}
    for keyword in keywords:
        result[keyword] = word_search(doc_list, keyword) 
    return result


doc_list = ["The Learn Python Challenge Casino.", "They bought a car and a casino", "Casinoville"]
keywords = ['casino', 'they']
multi_word_search(doc_list, keywords)
# Out:
# {'casino': [0, 1], 'they': [1]}

# %%
# Concatenate strings with the + operator.

planet + ', we miss you.' # 'Pluto, we miss you.'
# print(planet) # Pluto
# Out:
# 'Pluto, we miss you.'

# %%
# + operator can only concatenate str (not "int") to str

position = 9
planet + ", you'll always be the " + position + "th planet to me."
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-bd66b42d0124> in <module>
#       2
#       3 position = 9
# ----> 4 planet + ", you'll always be the " + position + "th planet to me."
#
# TypeError: can only concatenate str (not "int") to str

# %%
# type casting 

str(1) #'1'
str(4.5) #'4.5'
# Out:
# 1

# %%
planet + ", you'll always be the " + str(position) + "th planet to me"
# Out:
# "Pluto, you'll always be the 9th planet to me"

# %%
# str.format()

# We call .format() on a "format string", where the Python values we want to insert are represented with {} 
#   placeholders. Addtioinally, we didn't even have to call str() to convert position from an int. format() takes 
#   care of that for us.

print("{}, you'll always be the {}th planet to me.".format(planet, position)) #Pluto, you'll always be the 9th planet to me.
print("Mohammed has {} balloons".format(27)) #Mohammed has 27 balloons

animal = "dog"
action = "bite"
print("Does your {} {}?".format(animal, action)) #Does your dog bite?


maria_string = "Maria loves {} and {}"
print(maria_string.format("math", "statistics")) #Maria loves math and statistics
# Out:
# Pluto, you'll always be the 9th planet to me.
# Mohammed has 27 balloons
# Does your dog bite?
# Maria loves math and statistics

# %%
# format() can do a lot more 

pluto_mass = 1.303 * 10**22
earth_mass = 5.9722 * 10**24
population = 52910390

"{} weighs about {:.2} kilograms ({:.3%} of Earth's mass). It is home to {:,} Plutonians.".format(
    planet, pluto_mass, pluto_mass / earth_mass, population,
)

# {:.2} - 2 decimal points   
# {:.3%} - 3 decimal points, format as percent 
# {:,}  - separate with commas
# Out:
# "Pluto weighs about 1.3e+22 kilograms (0.218% of Earth's mass). It is home to 52,910,390 Plutonians."

# %%
# Referring to format() arguments by index, starting from 0

s = """Pluto's a {0}.
No, it's a {1}.
{0}!
{1}!""".format('planet', 'dwarf planet')
print(s)
# Out:
# Pluto's a planet.
# No, it's a dwarf planet.
# planet!
# dwarf planet!

# %%
my_string = "sebastian thrun"
a='defg'

my_string.capitalize() #'Sebastian thrun'
my_string.casefold() # return a verson of the sting that is suitable for caseless comparision, if string was "sebasTian"
# it would have returned "sebastian"
my_string.encode() #b'sebastian thrun'
my_string.isalnum() #False
my_string.isalpha() #False - as it contains space (which is character)
my_string.isdecimal() #False
my_string.isdigit() #False
my_string.isidentifier() #False
my_string.islower() #True
my_string.isnumeric() #False
my_string.isprintable() #True
my_string.isspace() #False
my_string.istitle() #False
my_string.isupper() #False
my_string.join(a) #'dsebastian thrunesebastian thrunfsebastian thrung'
# Out:
# 'dsebastian thrunesebastian thrunfsebastian thrung'
