# %% [markdown]
# # Object

# %% [markdown]
# * Everything in python is an object (int, floats, strings, dictionaries, boolean, class,  etc)
# * An object is an instance of a particular type (data type, class) .
# * Instance of a class is object (check classes notebook)
#     * e.g. circle class; red circle, yellow circle, pink circle
# * Objects can also carry around functions
# * method - A function attached to an object.
# * type() - used to find out the type of object
# * attributes - Non-function things attached to an objet, such as imag

# %% [markdown]
# Every time we create an integer, we are creating an instance of type integer, or we are creating an integer object. In this case, we are creating five instances of type integer or five integer objects.

# %% [markdown]
# ![Screenshot%202021-12-09%20at%2018.13.28.jpg](attachment:Screenshot%202021-12-09%20at%2018.13.28.jpg)

# %% [markdown]
# Similarly, every time we create a list, we are creating an instance of type list, or we are creating a list object. In this case, we are creating five instances of type list or five list objects. (nice figure in video)

# %% [markdown]
# ![Screenshot%202021-12-09%20at%2018.14.11.jpg](attachment:Screenshot%202021-12-09%20at%2018.14.11.jpg)

# %% [markdown]
# <h3 id="instance">Instances of a Class: Objects and Attributes</h3>

# %% [markdown]
# An instance of an object is the realisation of a class, and in Figure below, we see three instances of the class circle. We give each object a name: red circle, yellow circle, and green circle. Each object has different attributes, so let's focus on the color attribute for each object.

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%203/images/ClassesObj.png" width="500" />

# %% [markdown]
# Three instances of the class Circle, or three objects of type Circle.

# %% [markdown]
# The colour attribute for the red Circle is the colour red, for the green Circle object the colour attribute is green, and for the yellow Circle the colour attribute is yellow.

# %% [markdown]
# Below are three instances of circle class and three instances of rectangle class (created using classes defined in Classes notebook by different parameters (radius, color in case of circle class and heigh, widgth and color in case of rectangle)

# %% [markdown]
# ![Screenshot%202021-12-09%20at%2018.27.46.jpg](attachment:Screenshot%202021-12-09%20at%2018.27.46.jpg)

# %% [markdown]
# Every object has the following:
# * a type,
# * internal data representation (a blueprint),
# * a set of functions called methods to interact with the data.

# %%
# Objects carry somethings around with them (methods). This stuff can be accessed using Pythons dot syntax
# For example, numbers in Python carry around an associated variable called imag representing their imaginary part. 

x = 12
# x is a real number, so its imaginary part is 0.
print(x.imag) # 0 
# Here's how to make a complex number, in case you've ever been curious:
c = 12 + 3j
print(c.real) #12.0
print(c.imag) #3.0
# Out:
# 0
# 12.0
# 3.0

# %%
# Functions carried by Objects 
# For example, numbers have a method called bit_length

x.bit_length #<function int.bit_length()>

# To actually call it, we add parentheses:
x.bit_length() # 4 (1100) # help(x.bit_length)
# Out:
# 4
